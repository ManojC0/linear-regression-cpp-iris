# %% [markdown]
# # This short notebook is used to visualise the Iris dataset, specifically plotting the sepal length against the petal length and then plotting the regression line where the gradient and y-intercept have been calculated in C++.

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# m and b are taken from the final output of the gradient descent C++ program.
m = 0.670863
b = -0.0269404
plt.scatter(df["SepalLengthCm"], df["PetalLengthCm"])
plt.plot(list(range(4,9)), [m * x + b for x in range(4,9)], color="red") # Plotting regression line.
plt.title("Sepal Length against Petal Length")
plt.xlabel("Sepal Length cm")
plt.ylabel("Petal Length cm", rotation='horizontal', ha='right')
# Out:
# Text(0, 0.5, 'Petal Length cm')

# %% [markdown]
# The graph above shows that the relationship being modelled by linear regression
